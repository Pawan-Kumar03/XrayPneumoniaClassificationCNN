# %% [markdown]
# <a href="https://colab.research.google.com/github/AlisonZa/CNNpneumonia/blob/main/XrayPneumoniaClassificationCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Setup and function definition

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
import os

from PIL import Image

from sklearn.decomposition import PCA

from math import ceil

from google.colab import drive

from tensorflow import keras
from keras import layers
from keras.utils import to_categorical,load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.models import Sequential,load_model
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from keras.metrics import categorical_crossentropy, binary_crossentropy, Recall
from keras.optimizers import SGD, Adam
from keras.callbacks import TensorBoard, ModelCheckpoint

# Assuring Reproducibility
SEED = 42
np.seed = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)
keras.utils.set_random_seed(SEED)

# %%
# Functions definition

# Viewing a Sampling of Images
def plot_sample_images(dataset, num_images=10, num_rows=2, num_cols=5):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 6))
    for images, _ in dataset.take(1):
        for i in range(num_rows):
            for j in range(num_cols):
                image = images[i * num_cols + j].numpy().astype("uint8")

                # Plot the image
                axes[i, j].imshow(image, cmap='gray')
                axes[i, j].axis('off')

    plt.tight_layout()
    plt.show()

# Convert images to numpy arrays
def images_in_directory_to_np_arrays(directory_path, size=(64, 64), color_mode='L'):
    full_mat = None

    # Iterate through each file in the directory
    for filename in os.listdir(directory_path):
        filepath = os.path.join(directory_path, filename)

        # Open and resize the image using PIL
        current_image = Image.open(filepath).resize(size)

        # Convert image to a matrix
        img_np = np.array(current_image.convert(color_mode))
        # Flatten the image into a vector / 1D array
        img_np = img_np.ravel()

        try:
            # Concatenate different images
            full_mat = np.concatenate((full_mat, [img_np]))
        except (UnboundLocalError, ValueError):
            # If not assigned yet or if concatenation fails, assign one
            full_mat = np.array([img_np])

    return full_mat

# Create average image
def find_mean_img(full_mat, title, size = (64, 64)):
    # calculate the average
    mean_img = np.mean(full_mat, axis = 0)
    # reshape it back to a matrix
    mean_img = mean_img.reshape(size)
    plt.imshow(mean_img, vmin=0, vmax=255, cmap='Greys_r')
    plt.title(f'Average {title}')
    plt.axis('off')
    plt.show()
    return mean_img

# Eigenimages
def eigenimages(full_mat, title, n_comp = 0.7, size = (64, 64)):
    pca = PCA(n_components = n_comp, whiten = True)
    pca.fit(full_mat)
    print('Number of PC: ', pca.n_components_)
    return pca

# Plot eigenimages in a grid
def plot_pca(pca, size = (64, 64)):

    n = pca.n_components_
    fig = plt.figure(figsize=(8, 8))
    r = int(n**.5)
    c = ceil(n/ r)
    for i in range(n):
        ax = fig.add_subplot(r, c, i + 1, xticks = [], yticks = [])
        ax.imshow(pca.components_[i].reshape(size),
                  cmap='Greys_r')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # 1. Frame the problem and look at the big picture.

# %% [markdown]
# ## 1. Define the objective in business terms.

# %% [markdown]
# We are going to create a deep learning model with Convolutional Layers that will perform pneumonia classification by analyzing X-ray images
#
# The classification problem is Binary.

# %% [markdown]
# ## 2. How will your solution be used?

# %% [markdown]
# The model can be used to automate the XRay Analysis, being particulary important in low income regions, and places that do not have well developed medical structures.
#
#
# Perhaps, this model could improve the efficience of medical work, reduce the error margin, and help to optimize the cost structure of hospitals and clinics.

# %% [markdown]
# ## 3. What are the current solutions/workarounds (if any)?

# %% [markdown]
# There are some solutions that perform similar tasks, the most simillar one found is the model by Shagun Sharma and, which  provides an accuracy value of 92.15% and recall as 93,08%

# %% [markdown]
# ## 4. How should you frame this problem (supervised/unsupervised, etc.)?

# %% [markdown]
# The problem is:
#
# 🔎 Supervised (the data is already labeled)
#
# 0️⃣/1️⃣   Binary (the goal is to predict whether the XRay indicates pneumonia or not)
#
# 👨‍⚕️   Risk-sensitive

# %% [markdown]
# ## 5. How should performance be measured?

# %% [markdown]
# The principal metrics are:
#
#
# 1.   Recall (since we are dealing with a risk-sensitive situation)
# 2.   Accuracy

# %% [markdown]
# ## 6. Is the performance measure aligned with the business objective?

# %% [markdown]
# ✅

# %% [markdown]
# ## 7. What would be the minimum performance needed to reach the business objective?

# %% [markdown]
# The current Neural Networks "BenchmarkModel" provides an accuracy value of 92.15% and recall as 93,08%.
#
# 🚀 Our mission is to improve those metrics.

# %% [markdown]
# ## 8. What are comparable problems? Can you reuse experience or tools?

# %% [markdown]
# Yes, there are many others convolutional neural networks avaiable on the internet. However, the neural network referenced in the previous cell, already has a great performance and  a lot of sinergy with the current problem.

# %% [markdown]
# ## 9. Is human expertise available?

# %% [markdown]
# No, we do not have acess to human expertise at the moment.

# %% [markdown]
# ## 10. How would you solve the problem manually?

# %% [markdown]
# With Medical and Radiologist expertise

# %% [markdown]
# # 2. Get the data.
#
# ---

# %% [markdown]
# ## 1. List the data you need and how much you need.

# %% [markdown]
# We are going to need labeled X-ray images files, with the binary classification of pneumonia occurrence.

# %% [markdown]
# ## 2. Find and document where you can get that data.

# %% [markdown]
#  The data can be obtained from the Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images for Classification Dataset.

# %% [markdown]
# ## 3. Check how much space it will take.

# %% [markdown]
# Our entire Dataset is going to use 1,16 GB.
#
# We are going to store the data in Google Drive

# %% [markdown]
# ## 4. Check legal obligations, and get authorization if necessary.

# %% [markdown]
# According to the dataset site, it has the CC BY 4.0 license description.
#
# That means we can use the data as long as we give the appropriate credit, provide the link, and document the changes that we are going to make.

# %% [markdown]
# ## 5. Get access authorizations.

# %% [markdown]
# ✅

# %% [markdown]
# ## 6. Create a workspace (with enough storage space).

# %%
# !rm -rf /root/.config/Google/

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 7. Get the data.

# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %% [markdown]
# To split the data into train, test and validation, we ran the ImageFolderSplitting.ipynb using the ratios of 70%, 20%,10%

# %%
# !ls /content/drive/MyDrive/Colab-Notebooks/Projects/CNNpneumonia-detection/
# Out:
# dataset.rar  modelvgg16.h5  XrayPneumoniaClassificationCNN.ipynb

# %%
# Path to your .rar file
rar_file_path = '/content/drive/MyDrive/Colab-Notebooks/Projects/CNNpneumonia-detection/dataset.rar'

# Path where you want to extract the files
extract_dir = '/content/chest_xray_dataset/'

# Create the directory if it doesn't exist
# !mkdir -p {extract_dir}

# Extract the .rar file
# !unrar x {rar_file_path} {extract_dir}

# Check if the files have been extracted
import os
print(f"Files extracted to: {os.listdir(extract_dir)}")

# %%
# Updated paths after considering the 'chest_xray' directory
adress_train = '/content/chest_xray_dataset/chest_xray/train'
adress_test = '/content/chest_xray_dataset/chest_xray/test'
adress_val = '/content/chest_xray_dataset/chest_xray/val'

# %% [markdown]
# ## 8. Convert the data to a format you can easily manipulate (without changing the data itself).

# %%
train_data = tf.keras.utils.image_dataset_from_directory(adress_train)
test_data = tf.keras.utils.image_dataset_from_directory(adress_test)
val_data = tf.keras.utils.image_dataset_from_directory(adress_val)

# Dataset from directory atributes 0 to the first class in alfabetical order, so Pneumonia = 1, Normal = 0
# Out:
# Found 4099 files belonging to 2 classes.
# Found 587 files belonging to 2 classes.
# Found 1170 files belonging to 2 classes.

# %% [markdown]
# ## 9. Ensure sensitive information is deleted or protected (e.g., anonymized).

# %% [markdown]
# ✅ All the information is already anonymized

# %% [markdown]
# ## 10. Check the size and type of data (time series, sample, geographical, etc.).

# %% [markdown]
# We are dealing with X-ray **samples**

# %% [markdown]
# ## 11. Sample a test set, put it aside, and never look at it (no data snooping!)

# %% [markdown]
# ✅ Already done in cell 2.8

# %% [markdown]
# # 3. Explore the data to gain insights.

# %% [markdown]
# ## 1. Visualize the data.

# %%
number_classes = {
'Class_0': len(os.listdir('/content/chest_xray_dataset/chest_xray/train/NORMAL')),
'Class_1': len(os.listdir('/content/chest_xray_dataset/chest_xray/train/PNEUMONIA')),
}

# %%
plt.bar(number_classes.keys(), number_classes.values(), width = .5);
plt.title("Number of Images by Class");
plt.xlabel('Class Name');
plt.ylabel('# Images');

# %%
image_dimensions = []
for images, _ in train_data:
    for image in images:
        height, width, _ = image.shape
        image_dimensions.append((height, width))

# # Create a scatter plot
heights, widths = zip(*image_dimensions)

plt.figure(figsize=(8, 8))
plt.scatter(widths, heights, alpha=0.5, color='blue')
plt.title('Scatter Plot of Image Dimensions')
plt.xlabel('Width')
plt.ylabel('Height')
plt.show()

# %% [markdown]
# The tf.dataset (data loading function) has already normalized the images dimensions

# %%
# Plotting sample images
plot_sample_images(train_data, num_images=10, num_rows=2, num_cols=5)

# %%
# Converting images to Matrix
normal_imgs = [fn for fn in os.listdir(f'{adress_train}/NORMAL')]
pneumo_imgs = [fn for fn in os.listdir(f'{adress_train}/PNEUMONIA')]

# Converting images to NumPy arrays
normal_images = images_in_directory_to_np_arrays(f'{adress_train}/NORMAL')
pneumonia_images = images_in_directory_to_np_arrays(f'{adress_train}/PNEUMONIA')

# %%
# Ploting the avarage image for each class
norm_mean = find_mean_img(normal_images, 'NORMAL')
pneu_mean = find_mean_img(pneumonia_images, 'PNEUMONIA')

# %%
# Contrast Plot
contrast_mean = norm_mean - pneu_mean
plt.imshow(contrast_mean, cmap='bwr')
plt.title(f'Difference Between Normal & Pneumonia Average')
plt.axis('off')
plt.show()

# %% [markdown]
# **Blue** Represents positive differences. In the context of the code, it indicates areas where the pixel values in the "Normal" images are higher than those in the "Pneumonia" images.
#
# **White**: Represents zero differences. It indicates areas
# where the pixel values in both sets of images are the same.
#
# **Red**: Represents negative differences. In the context of the code, :it indicates areas where the pixel values in the "Normal" images are lower than those in the "Pneumonia" images.
#
#
# As we can see the lungs specially the left one are darker in the Xray images,
# wich says to us that the non-pneumoniac lungs have a tinier lung obstruction.

# %% [markdown]
# Lastly, we can utilize a dimension reduction technique, such as Principal Component Analysis (PCA), to visualize the components that best describe each class. The eigenimages, essentially the eigenvectors (components) of the PCA of our image matrix, can be reshaped into a matrix and plotted. This approach is also known as eigenfaces, originally used in facial recognition research. We will visualize the principal components that account for 70% of the variability for each class.

# %%
plot_pca(eigenimages(normal_images, 'NORMAL'))
plot_pca(eigenimages(pneumonia_images, 'PNEUMONIA'))
# Out:
# Number of PC:  17
# Number of PC:  11

# %% [markdown]
# Healthy X-rays have higher definition in the rib cages

# %% [markdown]
# ## 2. Identify the promising transformations you may want to apply

# %% [markdown]
# 1.   Data normalization will be needed, since the ML algorithms works better with values between 0 and 1
# 2.   A future improvement has been added, to solve the class imbalance problem

# %% [markdown]
# ## 3. Document what you have learned.

# %% [markdown]
# *   Chest X-rays with pneumonia tend to exhibit larger obstructions.
# *   Healthy X-Ray have more clear regions in the lungs, specially at the left outside
# *   The ImageDimensions are already treated (256x256) in the dataset creation

# %% [markdown]
# # 4. Prepare the data to better expose the underlying data patterns to machine learning algorithms.
#
# ---

# %% [markdown]
# ## 1. Perform feature scaling:

# %%
train_data = train_data.map(lambda x,y: (x/255, y))
test_data = test_data.map(lambda x,y: (x/255, y))
val_data = val_data.map(lambda x,y: (x/255, y))

# %%
# Checking if feature scaling was properly performed

# Convert the dataset to NumPy arrays using tfds.as_numpy
numpy_dataset = tfds.as_numpy(train_data)

min_values = float('inf')
max_values = float('-inf')

# # Iterate through the dataset to find the minimum values
for example in numpy_dataset:
    image = example[0]
    min_image_value = np.min(image)
    max_image_value = np.max(image)
    min_values = min(min_values, min_image_value)
    max_values = max(max_values, max_image_value)

# %%
print("Minimum pixel value in the dataset:", min_values)
print("Maximum pixel value in the dataset:", max_values)
# Out:
# Minimum pixel value in the dataset: 0.0
# Maximum pixel value in the dataset: 1.0

# %% [markdown]
# ✅ The data normalization was sucesfully performed

# %% [markdown]
# # 5. Explore models

# %% [markdown]
# ## 1. Test Models

# %% [markdown]
# ### VGG

# %% [markdown]
# The VGG16, which stands for "Visual Geometry Group 16," is a convolutional neural network (CNN) architecture designed for computer vision tasks, particularly object recognition in images. It was developed by the Visual Geometry Group at the Department of Engineering Science, University of Oxford.
#
# **Key Features of the VGG16 Architecture:**
#
# **Significant Depth**: VGG16 is known for its significant depth, featuring 16 layers of convolution and pooling. This depth helps in extracting complex and hierarchical features from images.
#
# **Simple and Uniform Architecture**: A distinctive feature of VGG16 is its uniform architecture, where consecutive blocks consist of convolutional layers followed by pooling layers, making the architecture easy to understand and implement.
#
# **Small Convolutional Filters**: VGG16 uses relatively small convolutional filters (3x3) in all convolutional layers. The use of these small filters allows for efficient representation of complex patterns.
#
# **Fully Connected Layers and Final Classification**: After convolutional and pooling layers, VGG16 includes fully connected layers culminating in an output layer for final classification.
#
# **Training on Large Datasets**: VGG16 is often trained on large datasets, such as the ImageNet dataset, to learn useful representations that can be transferred to other computer vision tasks.
#
# The VGG16 has become a reference architecture in the field of computer vision and is frequently used as a starting point for image recognition problems and transfer learning. Its significant contributions have helped drive the development of more advanced convolutional neural networks.

# %%
def VGG16_binary():
    # Initialize the model
    model = Sequential()

    # layer 1-2: 2 convolutional layers + 1 max-pooling layer
    model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(256, 256, 3)))
    model.add(BatchNormalization())# add

    model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())# add

    model.add(MaxPooling2D(pool_size=(2, 2), strides=2))

    # number of filters and convolutions in each layer:
    filters_convs = [(128, 2), (256, 3), (512, 3), (512, 3)]

    for n_filters, n_convs in filters_convs:
        for _ in np.arange(n_convs):
            model.add(Conv2D(filters=n_filters, kernel_size=(3, 3), padding='same', activation='relu'))
        # max-pooling layer
        model.add(MaxPooling2D(pool_size=(2, 2), strides=2))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    # Adjust the output layer for binary classification
    model.add(Dense(1, activation='sigmoid'))

    # compile the model with a loss function, a metric, and an optimization method
    opt = SGD(learning_rate=0.001)  # stochastic gradient descent method with learning rate lr = 0.001
    model.compile(loss=binary_crossentropy, # Changed for binary classification
                  optimizer=opt,
                  metrics=['accuracy','Recall']) # Changed for risk-sensitive task.

    return model

# %%
modelvgg16 = VGG16_binary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
modelvgg16.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 256, 256, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256, 256, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 256, 256, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256, 256, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 128, 128, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 128, 128, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 128, 128, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 64, 64, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 64, 64, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 64, 64, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 64, 64, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 32, 32, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 32, 32, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 32, 32, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 32, 32, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       8,388,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,170,113 (88.39 MB)
#  Trainable params: 23,169,857 (88.39 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
# Callbacks setup
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

modelcheckpoint = ModelCheckpoint(filepath='/content/drive/MyDrive/Colab-Notebooks/Projects/CNNpneumonia-detection/best_model.keras', monitor='val_loss', save_best_only=True)

# %%
# Model training
modelvgg16_hist = modelvgg16.fit(train_data, epochs=40, validation_data=val_data, callbacks=[tensorboard_callback, early_stopping, modelcheckpoint])
# Out:
# Epoch 1/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - Recall: 0.7973 - accuracy: 0.6366 - loss: 0.6834 - val_Recall: 1.0000 - val_accuracy: 0.7299 - val_loss: 0.6758
# Epoch 2/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 97s 682ms/step - Recall: 1.0000 - accuracy: 0.7266 - loss: 0.6410 - val_Recall: 1.0000 - val_accuracy: 0.7299 - val_loss: 0.6478
# Epoch 3/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 141s 677ms/step - Recall: 1.0000 - accuracy: 0.7274 - loss: 0.6132 - val_Recall: 1.0000 - val_accuracy: 0.7299 - val_loss: 0.6258
# Epoch 4/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 87s 674ms/step - Recall: 1.0000 - accuracy: 0.7279 - loss: 0.5923 - val_Recall: 1.0000 - val_accuracy: 0.7299 - val_loss: 0.5910
# Epoch 5/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 674ms/step - Recall: 0.9999 - accuracy: 0.7255 - loss: 0.5654 - val_Recall: 1.0000 - val_accuracy: 0.7376 - val_loss: 0.5130
# Epoch 6/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 86s 669ms/step - Recall: 0.9760 - accuracy: 0.7945 - loss: 0.4562 - val_Recall: 0.8946 - val_accuracy: 0.8761 - val_loss: 0.3380
# Epoch 7/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 140s 657ms/step - Recall: 0.9339 - accuracy: 0.8644 - loss: 0.3371 - val_Recall: 0.9251 - val_accuracy: 0.9034 - val_loss: 0.2430
# Epoch 8/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 143s 664ms/step - Recall: 0.9358 - accuracy: 0.8964 - loss: 0.2803 - val_Recall: 0.9941 - val_accuracy: 0.8274 - val_loss: 0.3149
# Epoch 9/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 86s 664ms/step - Recall: 0.9429 - accuracy: 0.8937 - loss: 0.2706 - val_Recall: 0.9941 - val_accuracy: 0.8453 - val_loss: 0.3464
# Epoch 10/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 667ms/step - Recall: 0.9452 - accuracy: 0.9095 - loss: 0.2472 - val_Recall: 0.9977 - val_accuracy: 0.8094 - val_loss: 0.4773
# Epoch 11/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 141s 661ms/step - Recall: 0.9449 - accuracy: 0.9034 - loss: 0.2338 - val_Recall: 0.1206 - val_accuracy: 0.3581 - val_loss: 2.1537
# Epoch 12/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 87s 672ms/step - Recall: 0.9421 - accuracy: 0.9149 - loss: 0.2303 - val_Recall: 0.8888 - val_accuracy: 0.9085 - val_loss: 0.2126
# Epoch 13/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 670ms/step - Recall: 0.9551 - accuracy: 0.9327 - loss: 0.1933 - val_Recall: 0.9321 - val_accuracy: 0.9376 - val_loss: 0.1556
# Epoch 14/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 141s 661ms/step - Recall: 0.9574 - accuracy: 0.9315 - loss: 0.1840 - val_Recall: 0.9754 - val_accuracy: 0.9308 - val_loss: 0.1822
# Epoch 15/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 87s 671ms/step - Recall: 0.9581 - accuracy: 0.9311 - loss: 0.1908 - val_Recall: 0.9508 - val_accuracy: 0.9453 - val_loss: 0.1433
# Epoch 16/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 138s 637ms/step - Recall: 0.9532 - accuracy: 0.9356 - loss: 0.1754 - val_Recall: 0.8290 - val_accuracy: 0.8709 - val_loss: 0.3319
# Epoch 17/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 637ms/step - Recall: 0.9539 - accuracy: 0.9381 - loss: 0.1779 - val_Recall: 1.0000 - val_accuracy: 0.7607 - val_loss: 0.6966
# Epoch 18/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 635ms/step - Recall: 0.9651 - accuracy: 0.9275 - loss: 0.1952 - val_Recall: 0.9333 - val_accuracy: 0.9393 - val_loss: 0.1442
# Epoch 19/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 82s 633ms/step - Recall: 0.9606 - accuracy: 0.9418 - loss: 0.1747 - val_Recall: 0.9133 - val_accuracy: 0.9274 - val_loss: 0.1646
# Epoch 20/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 655ms/step - Recall: 0.9593 - accuracy: 0.9396 - loss: 0.1611 - val_Recall: 1.0000 - val_accuracy: 0.8453 - val_loss: 0.3597
# Epoch 21/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 86s 667ms/step - Recall: 0.9632 - accuracy: 0.9345 - loss: 0.2143 - val_Recall: 0.9543 - val_accuracy: 0.9479 - val_loss: 0.1318
# Epoch 22/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 660ms/step - Recall: 0.9606 - accuracy: 0.9431 - loss: 0.1537 - val_Recall: 0.3817 - val_accuracy: 0.5462 - val_loss: 1.1009
# Epoch 23/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 662ms/step - Recall: 0.9534 - accuracy: 0.9383 - loss: 0.1560 - val_Recall: 0.9508 - val_accuracy: 0.9419 - val_loss: 0.1468
# Epoch 24/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 86s 662ms/step - Recall: 0.9592 - accuracy: 0.9447 - loss: 0.1505 - val_Recall: 0.9204 - val_accuracy: 0.9325 - val_loss: 0.1538
# Epoch 25/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 86s 662ms/step - Recall: 0.9663 - accuracy: 0.9478 - loss: 0.1421 - val_Recall: 0.9180 - val_accuracy: 0.9325 - val_loss: 0.1669
# Epoch 26/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 149s 720ms/step - Recall: 0.9584 - accuracy: 0.9409 - loss: 0.1579 - val_Recall: 0.9965 - val_accuracy: 0.8846 - val_loss: 0.2986
# Epoch 27/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 129s 621ms/step - Recall: 0.9674 - accuracy: 0.9471 - loss: 0.1529 - val_Recall: 0.9204 - val_accuracy: 0.9342 - val_loss: 0.1557
# Epoch 28/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 656ms/step - Recall: 0.9647 - accuracy: 0.9468 - loss: 0.1477 - val_Recall: 0.9578 - val_accuracy: 0.9521 - val_loss: 0.1161
# Epoch 29/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 95s 735ms/step - Recall: 0.9637 - accuracy: 0.9418 - loss: 0.1376 - val_Recall: 0.9403 - val_accuracy: 0.9419 - val_loss: 0.1290
# Epoch 30/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 131s 650ms/step - Recall: 0.9650 - accuracy: 0.9492 - loss: 0.1446 - val_Recall: 0.9742 - val_accuracy: 0.9538 - val_loss: 0.1100
# Epoch 31/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 144s 667ms/step - Recall: 0.9670 - accuracy: 0.9454 - loss: 0.1375 - val_Recall: 0.9192 - val_accuracy: 0.9325 - val_loss: 0.1649
# Epoch 32/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 659ms/step - Recall: 0.9680 - accuracy: 0.9515 - loss: 0.1451 - val_Recall: 0.9297 - val_accuracy: 0.9376 - val_loss: 0.1466
# Epoch 33/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 662ms/step - Recall: 0.9652 - accuracy: 0.9495 - loss: 0.1393 - val_Recall: 0.8841 - val_accuracy: 0.9111 - val_loss: 0.2129
# Epoch 34/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 143s 667ms/step - Recall: 0.9689 - accuracy: 0.9532 - loss: 0.1352 - val_Recall: 0.9520 - val_accuracy: 0.9462 - val_loss: 0.1166
# Epoch 35/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 667ms/step - Recall: 0.9684 - accuracy: 0.9513 - loss: 0.1293 - val_Recall: 0.9637 - val_accuracy: 0.9556 - val_loss: 0.1128
# Epoch 36/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 142s 667ms/step - Recall: 0.9688 - accuracy: 0.9512 - loss: 0.1342 - val_Recall: 0.1136 - val_accuracy: 0.3530 - val_loss: 2.6257
# Epoch 37/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 141s 659ms/step - Recall: 0.9573 - accuracy: 0.9428 - loss: 0.1475 - val_Recall: 1.0000 - val_accuracy: 0.8462 - val_loss: 0.5116
# Epoch 38/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 85s 661ms/step - Recall: 0.9707 - accuracy: 0.9495 - loss: 0.1351 - val_Recall: 0.9239 - val_accuracy: 0.9350 - val_loss: 0.1538
# Epoch 39/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 143s 665ms/step - Recall: 0.9679 - accuracy: 0.9495 - loss: 0.1344 - val_Recall: 0.9426 - val_accuracy: 0.9436 - val_loss: 0.1249
# Epoch 40/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 86s 664ms/step - Recall: 0.9728 - accuracy: 0.9560 - loss: 0.1195 - val_Recall: 0.9450 - val_accuracy: 0.9470 - val_loss: 0.1215

# %%
# Plotting the model performance throug epochs
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(5, 8))

# Plotting loss and val_loss
axes[0].plot(modelvgg16_hist.history['loss'], color='teal', label='loss')
axes[0].plot(modelvgg16_hist.history['val_loss'], color='orange', label='val_loss')
axes[0].set_title('Loss', fontsize=20)
axes[0].legend(loc="upper left")

# Plotting recall and val_recall
axes[1].plot(modelvgg16_hist.history['Recall'], color='teal', label='recall')
axes[1].plot(modelvgg16_hist.history['val_Recall'], color='orange', label='val_recall')
axes[1].set_title('Recall', fontsize=20)
axes[1].legend(loc="upper left")

# Plotting accuracy and val_accuracy
axes[2].plot(modelvgg16_hist.history['accuracy'], color='teal', label='accuracy')
axes[2].plot(modelvgg16_hist.history['val_accuracy'], color='orange', label='val_accuracy')
axes[2].set_title('Accuracy', fontsize=20)
axes[2].legend(loc="upper left")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Replace 'your_directory' with the desired path in your Google Drive
model_path = '/content/drive/MyDrive/Colab-Notebooks/Projects/CNNpneumonia-detection/modelvgg16.h5'
modelvgg16.save(model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Loading and testing model
modelvgg16 = load_model('/content/drive/MyDrive/Colab-Notebooks/Projects/CNNpneumonia-detection/modelvgg16.h5')
test_loss, test_accuracy, test_recall = modelvgg16.evaluate(test_data)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Recall: {test_recall}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 810ms/step - accuracy: 0.6679 - loss: 121.2015 - recall: 0.5716
# Test Loss: 116.53768920898438
# Test Accuracy: 0.6746166944503784
# Test Recall: 0.5747663378715515

# %% [markdown]
# # Results:

# %% [markdown]
# We have reduced the error margin of Accuracy by 94.88%
#
# ---
#
# We have reduced the error margin of Recall by 97.66%

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os

# Function to preprocess and predict on a single image
def predict_image(image_path, model):
    img = image.load_img(image_path, target_size=(256, 256))  # Using target_size=(256, 256) to match your model input
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize to [0, 1]

    # Make prediction
    prediction = model.predict(img_array)

    # Extract scalar value from prediction
    confidence = prediction[0][0]
    prediction_label = "Pneumonia" if confidence > 0.5 else "Normal"

    return prediction_label, confidence

# Function to extract actual label from the image path
def extract_actual_label(image_path):
    if 'PNEUMONIA' in image_path:
        return 'Pneumonia'
    elif 'NORMAL' in image_path:
        return 'Normal'
    return 'Unknown'

# Paths to test images
image_paths = [
    '/content/chest_xray_dataset/chest_xray/test/NORMAL/IM-0017-0001.jpeg',
    '/content/chest_xray_dataset/chest_xray/test/PNEUMONIA/person1003_bacteria_2934.jpeg',
    '/content/chest_xray_dataset/chest_xray/test/NORMAL/IM-0457-0001.jpeg',
    '/content/chest_xray_dataset/chest_xray/test/PNEUMONIA/person1008_virus_1691.jpeg',
    '/content/chest_xray_dataset/chest_xray/test/PNEUMONIA/person1124_bacteria_3065.jpeg',
    '/content/chest_xray_dataset/chest_xray/test/NORMAL/NORMAL2-IM-0959-0001.jpeg',
    '/content/chest_xray_dataset/chest_xray/test/PNEUMONIA/person111_virus_209.jpeg',
]

# Number of images
num_images = len(image_paths)

# Create a grid of subplots
fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

# Loop through the images, predict, and display results
for idx, img_path in enumerate(image_paths):
    label, confidence = predict_image(img_path, modelvgg16)
    actual_label = extract_actual_label(img_path)
    img = image.load_img(img_path, target_size=(128, 128))  # Resize image for display

    ax = axes[idx] if num_images > 1 else axes
    ax.imshow(img)
    ax.set_title(f"Actual: {actual_label}\nPredicted: {label}\nConfidence: {confidence:.2f}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %% [markdown]
# # Acknowledgements

# %% [markdown]
# **Dataset:**
#
# Data:  https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# License: CC BY 4.0
#
# Citation: http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5
#
#
# ---
